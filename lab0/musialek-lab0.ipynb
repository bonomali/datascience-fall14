# %%
import matplotlib

# %%
import pandas

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('Test plot');

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 15)
pd.set_option('display.line_width', 400)
pd.set_option('display.mpl_style', 'default')
import matplotlib as mpl
font = { 'family': 'serif',
        'style': 'normal',
        'size' : 22}
mpl.rc('font', **font)

# %%
cancer_data = pd.read_csv("/home/terrapin/UMCP828-F14/lab0/cancer_numbers_2010.csv")

# %%
cancer_data[:5]
# Out:
#      Age Group  Count
# 0     < 1 year   1007
# 1    1-4 years   3588
# 2    5-9 years   2495
# 3  10-14 years   2724
# 4  15-19 years   4465
#
# [5 rows x 2 columns]

# %%
cancer_data.median()
# Out:
# Count    48193
# dtype: float64

# %%
cancer_data['Count']
# Out:
# 0       1007
# 1       3588
# 2       2495
# 3       2724
# 4       4465
# 5       7278
# 6      11924
# 7      17621
# 8      27475
# 9      48193
# 10     84451
# 11    130254
# 12    165759
# 13    200629
# 14    209108
# 15    184707
# 16    160499
# 17    129829
# 18    116198
# Name: Count, dtype: int64

# %%
cancer_data.mean()
# Out:
# Count    79379.157895
# dtype: float64

# %%
cancer_data.plot(kind='bar')

# %%
col_index = cancer_data[['Age Group']]

# %%
cancer_data
# Out:
#       Age Group   Count
# 0      < 1 year    1007
# 1     1-4 years    3588
# 2     5-9 years    2495
# 3   10-14 years    2724
# 4   15-19 years    4465
# 5   20-24 years    7278
# 6   25-29 years   11924
# 7   30-34 years   17621
# 8   35-39 years   27475
# 9   40-44 years   48193
# 10  45-49 years   84451
# 11  50-54 years  130254
# 12  55-59 years  165759
# 13  60-64 years  200629
# 14  65-69 years  209108
# 15  70-74 years  184707
# 16  75-79 years  160499
# 17  80-84 years  129829
# 18    85+ years  116198
#
# [19 rows x 2 columns]

# %%
cancer_data2 = pd.read_csv("/home/terrapin/UMCP828-F14/lab0/cancer_numbers_2010.csv", index_col=0)

# %%
cancer_data2.plot(kind='bar')

# %%
import matplotlib as mpl
font = { 'family': 'serif',
        'style': 'normal',
        'size' : 14}
mpl.rc('font', **font)

# %%
cancer_data3 = pd.read_csv("/home/terrapin/UMCP828-F14/lab0/cancer_numbers_2010.csv", index_col=0)

# %%
cancer_data3.plot(kind='bar')

# %%
cancer_data3.plot(kind='bar', title="Cancer Incidence Rates in the US for 2010")

# %%
cancer_data3.plot(kind='bar', title="Cancer Incidence Rates in the US for 2010", figsize=(12,10))
